# %%
import pandas as pd

# %%
df = pd.read_csv("Table data.csv")

# %%
df
# Out:
#         Content                                        Video title  \
# 0         Total                                                NaN
# 1   9FKyCGTLn9I  অনুশীলনী ৪.১ ( ১৪ নাম্বার অঙ্কের সমাধান ) [ অধ...
# 2   SKtfjm0t2RQ  অনুশীলনী ২.১ এর প্রাথমিক আলোচনা  [ অধ্যায় ২ঃ ম...
# 3   qPfyeTS1QJY  Class 7 Math Vognangsher  losagu O gosagu | ভগ...
# 4   OaLdfjKknL0  অনুশীলনী ৪.১ (১। ক,খ,গ) [ অধ্যায় ৪ঃ বীজগণিতীয় ...
# 5   j2OArECH_8E  অনুশীলনী ২.১ (১৩ নং অঙ্কের সমাধান [ দ্বিতীয়  ...
# 6   44boEbYKLCE  অনুশীলনী ২.১ এর (২ ও ৩ নং অঙ্কের সমাধান)  [ অধ...
# 7   gCg8mf32StQ  অনুশীলনী ৪.১ ( ১৩ নং  অঙ্কের[ ক-খ] সমাধান ) [ ...
# 8   NPTYqlSk8VY  অনুশীলনী ২.১ (১ নং অঙ্কের সমাধান) [ অধ্যায় ২ঃ ...
# 9   cZHy56-xQeI  অনুশীলনী ৪.২ ( ৬ থেকে ১০ নং  অঙ্কের সমাধান ) [...
# 10  gUYwFHc5Zck  অজানা রাশির সূচক,গুণ ও তাদের প্রয়োগ || ojana ...
# 11  T8Uw_jvsZ64  অনুশীলনী ২.১ (১৩ নং অঙ্কের সমাধান [ প্রথম সমাধ...
# 12  YypJS-YaAhI  অজানা রাশির সূচক,গুণ ও তাদের প্রয়োগ || ojana ...
# ...

# %%
df = df.drop(columns=['Content', 'Video title', 'Video publish time'])

# %%
df
# Out:
#     Views  Watch time (hours)  Subscribers  Impressions  \
# 0    1222             19.7626           59        21855
# 1     108              2.7011           16          914
# 2      89              1.3378            1          638
# 3      84              1.4279            2         1899
# 4      82              1.0320            5          903
# 5      74              0.7177            0         1757
# 6      71              0.9985            1         1028
# 7      71              0.9881            1          994
# 8      58              0.8169            2          751
# 9      55              1.2650            4          496
# 10     52              1.1243            0         2197
# 11     49              0.5011            0         1082
# 12     43              1.6110            0         1356
# 13     35              0.6656            1          875
# 14     33              0.2873            1          392
# 15     31              0.6831            0          476
# ...

# %%
subscribers_col = df['Subscribers']
df = df.drop(columns=['Subscribers'])
df['Subscribers'] = subscribers_col

# %%
df
# Out:
#     Views  Watch time (hours)  Impressions  \
# 0    1222             19.7626        21855
# 1     108              2.7011          914
# 2      89              1.3378          638
# 3      84              1.4279         1899
# 4      82              1.0320          903
# 5      74              0.7177         1757
# 6      71              0.9985         1028
# 7      71              0.9881          994
# 8      58              0.8169          751
# 9      55              1.2650          496
# 10     52              1.1243         2197
# 11     49              0.5011         1082
# 12     43              1.6110         1356
# 13     35              0.6656          875
# 14     33              0.2873          392
# 15     31              0.6831          476
# 16     31              0.5813          440
# 17     29              0.3876          454
# 18     29              0.4660          872
# 19     28              0.3830          645
# 20     25              0.2778          637
# ...

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))  # Set the size of the plot

# Create a heatmap using seaborn
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

plt.title('Data Correlation Heatmap', fontsize=16)
plt.show()

# %%
# Clean the data (remove duplicates, missing values, etc.)
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)

# Analyze the data (calculate the correlation between views and likes)
corr = df["Views"].corr(df["Subscribers"])

# Visualize the data (create a scatter plot of views vs. likes)
plt.plot(df["Subscribers"], df["Views"],'g+-')
plt.xlabel("Views")
plt.ylabel("Subscribers")
plt.title(f"Correlation: {corr:.2f}")
plt.show()

# %%
# Clean the data (remove duplicates, missing values, etc.)
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)

# Analyze the data (calculate the correlation between views and likes)
corr = df["Views"].corr(df["Subscribers"])

# Visualize the data (create a scatter plot of views vs. likes)
plt.plot(df["Subscribers"], df["Watch time (hours)"],'')
plt.xlabel("Subscribers")
plt.ylabel("Watch time (hours)")
plt.title(f"Correlation: {corr:.2f}")
plt.scatter('Subscribers', 'Watch time (hours)')
plt.show()

# %% [markdown]
# # Model traning

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Subscribers', axis=1)
y = df['Subscribers']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
X_train
# Out:
#     Views  Watch time (hours)  Impressions  Impressions click-through rate (%)
# 21     25              0.2549          655                                3.51
# 0    1222             19.7626        21855                                4.31
# 12     43              1.6110         1356                                2.58
# 17     29              0.3876          454                                5.07
# 22     23              0.1263          536                                3.36
# 11     49              0.5011         1082                                3.05
# 13     35              0.6656          875                                3.20
# 15     31              0.6831          476                                5.25
# 1     108              2.7011          914                                7.22
# 4      82              1.0320          903                                6.09
# 5      74              0.7177         1757                                3.19
# ...

# %%
y_test
# Out:
# 9     4
# 25    0
# 8     2
# Name: Subscribers, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
linear_regressor = LinearRegression()
linear_regressor.fit(X_train, y_train)
y_pred = linear_regressor.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 0.17359420177972748
# R-squared: 0.9349021743326023

# %%
y_pred=linear_regressor.predict([[5000,1000.098,3000,100.8]])
# Out:
# C:\Users\Sihab\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"

# %%
y_pred
# Out:
# array([4530.51029683])
